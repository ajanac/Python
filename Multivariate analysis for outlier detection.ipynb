# %% [markdown]
# <h3> Multivariate Analysis for Outlier Detection </h3>

# %% [markdown]
# <img src="outlier.jpg">

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams 
import seaborn as sb

import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
rcParams['figure.figsize']=5,4
sb.set_style('whitegrid')

# %%
df=pd.read_csv(filepath_or_buffer='iris.data.csv',header=None,sep=',')

df.columns=['Sepal Length','Sepal Width','Petal Lentgh','Petal Width','Species']
data=df.ix[:,0:4].values
target=df.ix[:,4].values
df[:5]

sb.boxplot(x="Species",y='Sepal Length',data=df,palette='hls')

# %%
sb.pairplot(df,hue='Species',palette='hls')
