# %%
import numpy as np
import pandas as pd
import scipy 

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize']=4,5
sb.set_style('whitegrid')

# %% [markdown]
# <h3>
# Normalizing and Transforming Features with MinMaxScalar and fit_transform()
# </h3>

# %%
cars=pd.read_csv('mtcars.csv')
cars.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
mpg=cars.mpg
plt.plot(mpg)

# %%
mpg.describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
mpg_matrix=mpg.reshape(-1,1)
scaled=preprocessing.MinMaxScaler()
scaled_mpg=scaled.fit_transform(mpg_matrix)
plt.plot(scaled_mpg)
# Out:
# C:\Users\asathian\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# <h3> Using scale() to scale your features</h3>

# %%
standardarized_mpg=scale(mpg,axis=0,with_mean=False,with_std=False)
plt.plot(standardarized_mpg)

# %%
# Variable now has the standard normal distribution. 
stand_mpg=scale(mpg)
plt.plot(stand_mpg)
