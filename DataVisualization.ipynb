# %% [markdown]
# <h1> Data visualization </h1>
# <img src="data_visualization.png">

# %%
# Installing the Seaborn
! pip install Seaborn

# %%
# Packages for data analysis
import numpy as np 
from numpy.random import randn
import pandas as pd
from pandas import Series,DataFrame

# Packages for plotting
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
#Tells the matplot lib to print the data visualization within the python notebook, instead of opening it in 
#an external GUL

# %matplotlib inline

#Global Parametersization
# setting the width and height of the figure and the style
rcParams['figure.figsize']=5,4
sb.set_style("whitegrid")

# %%
# Plotting the line chart based on x y
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
plt.plot(x,y)

# %%
# Reading from a data set
college_scoreboard_data=pd.read_csv("/Users/ajanasathian/Desktop/AJDS/python_learning/Most-Recent-Cohorts-Scorecard-Elements.csv")

# %%
pctpell=college_scoreboard_data['PCTPELL']

# %%
pctpell.plot()

# %%
df=college_scoreboard_data[['PBI','HSI']]

# %%
df.plot()

# %%
# bar chart
plt.bar(x,y)
# Out:
# <Container object of 9 artists>

# %%
pctpell.plot(kind='bar')

# %%
# horizontal oriented barchart
pctpell.plot(kind='barh')

# %%
# Pie chart
x=[1,2,3,4,5,0]
plt.pie(x)
plt.show()

# %%
# Saving the pie chart. It will save in the working directory
plt.savefig('pie_chart.jpeg')
plt.show()

# %%
# %pwd
# Out:
# u'/Users/ajanasathian/Desktop/AJDS/python_learning'
